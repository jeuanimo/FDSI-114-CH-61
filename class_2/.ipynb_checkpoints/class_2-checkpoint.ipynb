# %%
my_list = []
my_list.append('a')
my_list.append('b')
my_list.append('c')
#pop the last element
my_list.pop()
top = my_list.pop()
my_list.append('d')
print(top)
my_list.pop()
print(my_list)

# %%
stack = []
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
print(stack[-1])

# %%
stack = []
if len(stack) == 0:
    print("Stack is empty")
else:
    print("Stack is not empty")

# %%
s = "HELLO"
lst = list(s)
reversed_lst = lst[::-1]
print(reversed_lst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 s = "HELLO"
# ----> 2 lst = word(s)
#       3 reversed_lst = lst[::-1]
#       4 print(reversed_lst)
#
# NameError: name 'word' is not defined
